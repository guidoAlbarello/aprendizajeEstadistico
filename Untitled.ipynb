# %%
import matplotlib.pyplot as plt
import math as math
import pandas as pd
import numpy as np

# %% [markdown]
# La normal multivariada viene dada por la siguiente función:

# %%
# %matplotlib inline
b = 10000
mean =[1,0]
cov = [[55,50],[0,55]]


n = np.random.multivariate_normal(mean, cov, int(b)).T

plt.scatter(n[0], n[1], s=1*3.14)

plt.show()
# Out:
# /home/event/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: covariance is not positive-semidefinite.
#   import sys
